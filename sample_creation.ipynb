# %%
from random import randrange
import pandas as pd

df = pd.read_csv('data/twitter_french_results_last.csv')

sample = {}

for i in range(20):
    rand = randrange(len(df))
    sample[rand] = df.iloc[rand]
    
sample_df = pd.DataFrame.from_dict(sample).transpose()
sample_df
# Out:
#        created_at             tweet_id  \
# 1160  Feb 29 2020  1233900486660677632
# 3330  Feb 27 2020  1233036705348902912
# 803   Feb 28 2020  1233541966966804480
# 1924  Mar 02 2020  1234623331799851009
# 5340  Mar 02 2020  1234569931074818048
# 6214  Mar 04 2020  1234992266856386560
# 968   Feb 29 2020  1233890871352942592
# 4634  Mar 01 2020  1234145758665793536
# 2506  Mar 03 2020  1234974412496990208
# 2621  Mar 03 2020  1234976356804358144
# 990   Feb 29 2020  1233901469914607622
# 4279  Feb 29 2020  1233759438445694976
# 4194  Feb 29 2020  1233718946685227008
# 4341  Feb 28 2020  1233482503144574976
# 184   Feb 27 2020  1233179198996537344
# 5690  Mar 03 2020  1234951241085616129
# 1862  Mar 02 2020  1234625416637374465
# 3406  Feb 27 2020  1232980289347104768
# 749   Feb 28 2020  1233533283394314240
# 3642  Feb 28 2020  1233434207801741312
#
#                                                    text lang  \
# 1160  @gst_ln @Eriadus Normal, elles se font instant...   fr
# ...

# %%
sample_df.to_csv('sample_df.csv')
